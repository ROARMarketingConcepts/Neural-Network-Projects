# %% [markdown]
# # Variational Auto-Encoder Neural Network

# %%
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
from torchvision import transforms
from torchvision.utils import save_image

# %%
# Define hyperparameters
image_size = 784
hidden_dim = 400
latent_dim = 20
batch_size = 128
epochs = 10

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# MNIST dataset
train_dataset = torchvision.datasets.MNIST(root='../../data',
                                           train=True,
                                           transform=transforms.ToTensor(),
                                           download=True)

train_loader = torch.utils.data.DataLoader(dataset=train_dataset,
                                           batch_size=batch_size, 
                                           shuffle=True)

test_dataset = torchvision.datasets.MNIST(root='../../data',
                                          train=False,
                                          transform=transforms.ToTensor())

test_loader = torch.utils.data.DataLoader(dataset=test_dataset,
                                          batch_size=batch_size, 
                                          shuffle=True)

# Create directory to save the reconstructed and sampled images (if directory not present)
sample_dir = 'results'
if not os.path.exists(sample_dir):
    os.makedirs(sample_dir)

# %% [markdown]
# ![vae](https://user-images.githubusercontent.com/30661597/78418103-a2047200-766b-11ea-8205-c7e5712715f4.png)

# %%
# VAE model
class VAE(nn.Module):
    def __init__(self):
        super(VAE, self).__init__()
        
        self.fc1 = nn.Linear(image_size, hidden_dim)
        self.fc2_mean = nn.Linear(hidden_dim, latent_dim)      # mean 
        self.fc2_logvar = nn.Linear(hidden_dim, latent_dim)    # log(variance)
        self.fc3 = nn.Linear(latent_dim, hidden_dim)
        self.fc4 = nn.Linear(hidden_dim, image_size)
        
    def encode(self, x):
        hidden = F.relu(self.fc1(x))
        mu = self.fc2_mean(hidden)
        log_var = self.fc2_logvar(hidden)
        return mu, log_var
    
    def reparameterize(self, mu, logvar):
        std_dev = torch.exp(logvar/2)
        epsilon = torch.randn_like(std_dev) # Normal distribution with standard deviation 'std_dev'
        return mu + epsilon * std_dev
    
    def decode(self, z):
        hidden = F.relu(self.fc3(z))
        out = torch.sigmoid(self.fc4(hidden))  # range of values for MNIST images is 0 to 1.
        return out
    
    def forward(self, x):
        # x: (batch_size, 1, 28,28) --> (batch_size, 784)
        mu, logvar = self.encode(x.view(-1, image_size))   # flatten x
        z = self.reparameterize(mu, logvar)
        reconstructed = self.decode(z)
        return reconstructed, mu, logvar

# Define model and optimizer
model = VAE().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

# %% [markdown]
# $Loss = -E[\log P(X | z)]+D_{K L}[N(\mu(X), \Sigma(X)) \| N(0,1)]$

# %% [markdown]
# #### $D_{K L}[N(\mu(X), \Sigma(X)) \| N(0,1)]=\frac{1}{2} \sum_{k}\left(\exp (\Sigma(X))+\mu^{2}(X)-1-\Sigma(X)\right)$

# %%
# Define Loss
def loss_function(reconstructed_image, original_image, mu, logvar):
    # reconstructed image is flattened, so we need to flatten the original image
    # also reduction = 'sum' because we are summing up terms for D_KL.
    bce = F.binary_cross_entropy(reconstructed_image, original_image.view(-1, 784), reduction = 'sum') 
    #############################################################################################
    # logvar, exp: (batch_size, 20)
    # kld = torch.sum(0.5 * torch.sum(logvar.exp() + mu.pow(2) - 1 - logvar, 1))  # (batch_size)
    # kld_sum = torch.sum(kld)
    #############################################################################################
    kld = 0.5 * torch.sum(logvar.exp() + mu.pow(2) - 1 - logvar)
    return bce + kld
    

# Train function
def train(epoch):
    model.train()
    train_loss = 0
    for i, (images, _) in enumerate(train_loader):
        images = images.to(device)
        reconstructed, mu, logvar = model(images)
        loss = loss_function(reconstructed, images, mu, logvar) # loss for all the batches
        optimizer.zero_grad()
        loss.backward()
        train_loss += loss.item()   
        optimizer.step()
        
        if i % 100 == 0:
            # we need to calculate loss.item()/len(images) = average loss per batch
            print("Train Epoch {} [Batch {}/{}]\tLoss: {:.3f}".format(epoch, i, len(train_loader), loss.item()/len(images)))
            
    print('=====> Epoch {}, Average Loss: {:.3f}'.format(epoch, train_loss/len(train_loader.dataset)))


# Test function
def test(epoch):
    model.eval()
    test_loss = 0
    with torch.no_grad():
        for batch_idx, (images, _) in enumerate(test_loader):
            images = images.to(device)
            reconstructed, mu, logvar = model(images)
            test_loss += loss_function(reconstructed, images, mu, logvar).item()
            if batch_idx == 0:
                comparison = torch.cat([images[:5], reconstructed.view(batch_size, 1, 28, 28)[:5]])
                save_image(comparison.cpu(), 'results/reconstruction_' + str(epoch) + '.png', nrow = 5)

    print('=====> Average Test Loss: {:.3f}'.format(test_loss/len(test_loader.dataset)))

# %%
# Main function
for epoch in range(1, epochs + 1):
    train(epoch)
    test(epoch)
    with torch.no_grad():
        # Get rid of the encoder and sample z from the gaussian ditribution and feed it to the decoder to generate samples
        sample = torch.randn(64,20).to(device)
        generated = model.decode(sample).cpu()
        save_image(generated.view(64,1,28,28), 'results/sample_' + str(epoch) + '.png')
# Out:
# Train Epoch 1 [Batch 0/469]	Loss: 546.478
# Train Epoch 1 [Batch 100/469]	Loss: 187.516
# Train Epoch 1 [Batch 200/469]	Loss: 161.313
# Train Epoch 1 [Batch 300/469]	Loss: 135.480
# Train Epoch 1 [Batch 400/469]	Loss: 126.959
# =====> Epoch 1, Average Loss: 164.368
# =====> Average Test Loss: 127.298
# Train Epoch 2 [Batch 0/469]	Loss: 126.973
# Train Epoch 2 [Batch 100/469]	Loss: 124.717
# Train Epoch 2 [Batch 200/469]	Loss: 118.453
# Train Epoch 2 [Batch 300/469]	Loss: 115.360
# Train Epoch 2 [Batch 400/469]	Loss: 115.287
# =====> Epoch 2, Average Loss: 121.258
# =====> Average Test Loss: 115.717
# Train Epoch 3 [Batch 0/469]	Loss: 118.217
# Train Epoch 3 [Batch 100/469]	Loss: 114.864
# Train Epoch 3 [Batch 200/469]	Loss: 111.956
# Train Epoch 3 [Batch 300/469]	Loss: 115.090
# Train Epoch 3 [Batch 400/469]	Loss: 112.972
# =====> Epoch 3, Average Loss: 114.441
# =====> Average Test Loss: 111.519
# Train Epoch 4 [Batch 0/469]	Loss: 116.376
# Train Epoch 4 [Batch 100/469]	Loss: 111.265
# Train Epoch 4 [Batch 200/469]	Loss: 115.301
# Train Epoch 4 [Batch 300/469]	Loss: 111.040
# Train Epoch 4 [Batch 400/469]	Loss: 108.261
# =====> Epoch 4, Average Loss: 111.450
# =====> Average Test Loss: 109.547
# Train Epoch 5 [Batch 0/469]	Loss: 108.592
# Train Epoch 5 [Batch 100/469]	Loss: 112.073
# Train Epoch 5 [Batch 200/469]	Loss: 111.795
# Train Epoch 5 [Batch 300/469]	Loss: 106.190
# Train Epoch 5 [Batch 400/469]	Loss: 109.851
# =====> Epoch 5, Average Loss: 109.644
# =====> Average Test Loss: 108.241
# Train Epoch 6 [Batch 0/469]	Loss: 112.014
# Train Epoch 6 [Batch 100/469]	Loss: 111.146
# Train Epoch 6 [Batch 200/469]	Loss: 109.561
# Train Epoch 6 [Batch 300/469]	Loss: 108.501
# Train Epoch 6 [Batch 400/469]	Loss: 110.592
# =====> Epoch 6, Average Loss: 108.486
# =====> Average Test Loss: 107.479
# Train Epoch 7 [Batch 0/469]	Loss: 110.963
# Train Epoch 7 [Batch 100/469]	Loss: 104.725
# Train Epoch 7 [Batch 200/469]	Loss: 104.896
# Train Epoch 7 [Batch 300/469]	Loss: 109.203
# Train Epoch 7 [Batch 400/469]	Loss: 109.601
# =====> Epoch 7, Average Loss: 107.665
# =====> Average Test Loss: 106.671
# Train Epoch 8 [Batch 0/469]	Loss: 103.495
# Train Epoch 8 [Batch 100/469]	Loss: 107.994
# Train Epoch 8 [Batch 200/469]	Loss: 107.090
# Train Epoch 8 [Batch 300/469]	Loss: 105.246
# Train Epoch 8 [Batch 400/469]	Loss: 105.372
# =====> Epoch 8, Average Loss: 107.006
# =====> Average Test Loss: 106.217
# Train Epoch 9 [Batch 0/469]	Loss: 102.201
# Train Epoch 9 [Batch 100/469]	Loss: 106.764
# Train Epoch 9 [Batch 200/469]	Loss: 108.017
# Train Epoch 9 [Batch 300/469]	Loss: 106.691
# Train Epoch 9 [Batch 400/469]	Loss: 106.470
# =====> Epoch 9, Average Loss: 106.529
# =====> Average Test Loss: 105.909
# Train Epoch 10 [Batch 0/469]	Loss: 103.228
# Train Epoch 10 [Batch 100/469]	Loss: 109.320
# Train Epoch 10 [Batch 200/469]	Loss: 108.548
# Train Epoch 10 [Batch 300/469]	Loss: 110.087
# Train Epoch 10 [Batch 400/469]	Loss: 109.170
# =====> Epoch 10, Average Loss: 106.147
# =====> Average Test Loss: 105.525
